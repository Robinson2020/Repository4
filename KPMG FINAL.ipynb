# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df= pd.read_excel('KPMG.xlsx')
df.head(10)
# Out:
#    gender  past_3_years_bike_related_purchases        DOB  \
# 0    Male                                   99 1953-10-22
# 1    Male                                   99 1954-03-18
# 2  Female                                   99 1954-04-02
# 3    Male                                   99 1954-04-11
# 4    Male                                   99 1954-05-26
# 5    Male                                   99 1954-07-24
# 6  Female                                   99 1954-10-27
# 7    Male                                   99 1955-04-19
# 8  Female                                   99 1955-04-25
# 9  Female                                   99 1955-11-08
#
#                  job_title job_industry_category     wealth_segment  \
# 0                      NaN              Property      Mass Customer
# 1         Internal Auditor                   NaN  Affluent Customer
# 2          General Manager                Health  Affluent Customer
# ...

# %%
df.isnull().sum()
# Out:
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     28
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
df['job_industry_category'].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64

# %%
df['job_title'].value_counts()
# Out:
# Business Systems Development Analyst    45
# Tax Accountant                          44
# Social Worker                           44
# Internal Auditor                        42
# Legal Assistant                         41
#                                         ..
# Programmer Analyst IV                    4
# Health Coach I                           3
# Health Coach III                         3
# Research Assistant III                   3
# Developer I                              1
# Name: job_title, Length: 195, dtype: int64

# %%
df['job_title'].value_counts()
# Out:
# Business Systems Development Analyst    45
# Tax Accountant                          44
# Social Worker                           44
# Internal Auditor                        42
# Legal Assistant                         41
#                                         ..
# Programmer Analyst IV                    4
# Health Coach I                           3
# Health Coach III                         3
# Research Assistant III                   3
# Developer I                              1
# Name: job_title, Length: 195, dtype: int64

# %%
df['job_title'].mode()
# Out:
# 0    Business Systems Development Analyst
# dtype: object

# %%
df['job_industry_category'].mode()
# Out:
# 0    Manufacturing
# dtype: object

# %%
df['tenure'].mode()
# Out:
# 0    7.0
# dtype: float64

# %%
df['DOB'].mode()
# Out:
# 0   1954-02-21
# 1   1957-05-15
# 2   1961-02-11
# 3   1962-01-14
# 4   1977-02-16
# 5   1980-09-01
# 6   1988-11-27
# 7   1995-06-11
# 8   1999-07-28
# dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
# gender                                 4000 non-null object
# past_3_years_bike_related_purchases    4000 non-null int64
# DOB                                    3972 non-null datetime64[ns]
# job_title                              3494 non-null object
# job_industry_category                  3344 non-null object
# wealth_segment                         4000 non-null object
# deceased_indicator                     4000 non-null object
# owns_car                               4000 non-null object
# tenure                                 3913 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 281.4+ KB

# %%
#Analysis of the various segments 
sns.set(rc={'figure.figsize':(25.7,10.27)})
sns.countplot(df['wealth_segment'])

# %%
df['job_industry_category'].fillna(df.job_industry_category.mode(), inplace=True)

# %%
df['job_title'].fillna(df.job_title.mode(), inplace=True)

# %%
df['tenure'].fillna(df.tenure.mean(), inplace=True)

# %%
df.head()
# Out:
#    gender  past_3_years_bike_related_purchases        DOB  \
# 0    Male                                   99 1953-10-22
# 1    Male                                   99 1954-03-18
# 2  Female                                   99 1954-04-02
# 3    Male                                   99 1954-04-11
# 4    Male                                   99 1954-05-26
#
#                               job_title job_industry_category  \
# 0  Business Systems Development Analyst              Property
# 1                      Internal Auditor                   NaN
# 2                       General Manager                Health
# 3                       Sales Associate    Financial Services
# 4                          Accountant I         Entertainment
#
#       wealth_segment deceased_indicator owns_car  tenure
# 0      Mass Customer                  N       No     9.0
# 1  Affluent Customer                  N       No     5.0
# 2  Affluent Customer                  N       No     1.0
# ...

# %%
df.isnull().sum()
# Out:
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     28
# job_title                              505
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# dtype: int64

# %%
df['job_industry_category'] = df['job_industry_category'].fillna('Manufacutring')
df.head()
# Out:
#    gender  past_3_years_bike_related_purchases        DOB  \
# 0    Male                                   99 1953-10-22
# 1    Male                                   99 1954-03-18
# 2  Female                                   99 1954-04-02
# 3    Male                                   99 1954-04-11
# 4    Male                                   99 1954-05-26
#
#                               job_title job_industry_category  \
# 0  Business Systems Development Analyst              Property
# 1                      Internal Auditor         Manufacutring
# 2                       General Manager                Health
# 3                       Sales Associate    Financial Services
# 4                          Accountant I         Entertainment
#
#       wealth_segment deceased_indicator owns_car  tenure
# 0      Mass Customer                  N       No     9.0
# 1  Affluent Customer                  N       No     5.0
# 2  Affluent Customer                  N       No     1.0
# ...

# %%
df['job_title'] = df['job_title'].fillna('Business Systems Development Analyst')
df.head(15)
# Out:
#     gender  past_3_years_bike_related_purchases        DOB  \
# 0     Male                                   99 1953-10-22
# 1     Male                                   99 1954-03-18
# 2   Female                                   99 1954-04-02
# 3     Male                                   99 1954-04-11
# 4     Male                                   99 1954-05-26
# 5     Male                                   99 1954-07-24
# 6   Female                                   99 1954-10-27
# 7     Male                                   99 1955-04-19
# 8   Female                                   99 1955-04-25
# 9   Female                                   99 1955-11-08
# 10    Male                                   99 1955-12-14
# 11    Male                                   99 1956-08-24
# 12  Female                                   99 1956-10-13
# 13  Female                                   99 1956-11-16
# 14    Male                                   99 1957-04-15
#
# ...

# %%
df.isnull().sum()
# Out:
# gender                                  0
# past_3_years_bike_related_purchases     0
# DOB                                    28
# job_title                               0
# job_industry_category                   0
# wealth_segment                          0
# deceased_indicator                      0
# owns_car                                0
# tenure                                  0
# dtype: int64

# %%
df['past_3_years_bike_related_purchases'].plot.box()

# %%
df['tenure'].plot.box()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
# gender                                 4000 non-null object
# past_3_years_bike_related_purchases    4000 non-null int64
# DOB                                    3972 non-null datetime64[ns]
# job_title                              4000 non-null object
# job_industry_category                  4000 non-null object
# wealth_segment                         4000 non-null object
# deceased_indicator                     4000 non-null object
# owns_car                               4000 non-null object
# tenure                                 4000 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 281.4+ KB

# %%
#extracting the month from the flight date
df['DOB'] = pd.to_datetime(df['DOB'])
df['year'] = df['DOB'].dt.year
df['month'] = df['DOB'].dt.month

# %%
df.head()
# Out:
#    gender  past_3_years_bike_related_purchases        DOB  \
# 0    Male                                   99 1953-10-22
# 1    Male                                   99 1954-03-18
# 2  Female                                   99 1954-04-02
# 3    Male                                   99 1954-04-11
# 4    Male                                   99 1954-05-26
#
#                               job_title job_industry_category  \
# 0  Business Systems Development Analyst              Property
# 1                      Internal Auditor         Manufacutring
# 2                       General Manager                Health
# 3                       Sales Associate    Financial Services
# 4                          Accountant I         Entertainment
#
#       wealth_segment deceased_indicator owns_car  tenure    year  month
# 0      Mass Customer                  N       No     9.0  1953.0   10.0
# 1  Affluent Customer                  N       No     5.0  1954.0    3.0
# ...

# %%
df.drop(['DOB', 'deceased_indicator'], axis=1)
# Out:
#       gender  past_3_years_bike_related_purchases  \
# 0       Male                                   99
# 1       Male                                   99
# 2     Female                                   99
# 3       Male                                   99
# 4       Male                                   99
# ...      ...                                  ...
# 3995  Female                                    0
# 3996  Female                                    0
# 3997  Female                                    0
# 3998    Male                                    0
# 3999  Female                                    0
#
#                                  job_title job_industry_category  \
# 0     Business Systems Development Analyst              Property
# 1                         Internal Auditor         Manufacutring
# 2                          General Manager                Health
# 3                          Sales Associate    Financial Services
# ...

# %%
sns.distplot(df['past_3_years_bike_related_purchases'])

# %%
sns.distplot(df['tenure'])

# %%
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Admin\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
fig = plt.figure(figsize = (7,7))
sns.barplot(x = 'owns_car', y = 'past_3_years_bike_related_purchases', data = df)

# %%
fig = plt.figure(figsize = (7,7))
sns.barplot(x = 'wealth_segment', y = 'past_3_years_bike_related_purchases', data = df)

# %%
fig = plt.figure(figsize = (15,15))
sns.barplot(x = 'job_industry_category', y = 'past_3_years_bike_related_purchases', data = df)

# %%
fig = plt.figure(figsize = (15,15))
sns.barplot(x = 'gender', y = 'past_3_years_bike_related_purchases', data = df)

# %%
df['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# M            1
# F            1
# Femal        1
# Name: gender, dtype: int64

# %%
fig = plt.figure(figsize = (22,15))
sns.barplot(x = 'year', y = 'past_3_years_bike_related_purchases', data = df)

# %%
fig = plt.figure(figsize = (7,12))
sns.lineplot(x = 'year', y = 'past_3_years_bike_related_purchases', data = df)

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
import pandas as pd
le=LabelEncoder()
df['wealth_segment']=le.fit_transform(df['wealth_segment'])
df['job_industry_category']=le.fit_transform(df['job_industry_category'])
df['job_title']=le.fit_transform(df['job_title'])
df['gender']=le.fit_transform(df['gender'])
df['owns_car']=le.fit_transform(df['owns_car'])
df['year']=le.fit_transform(df['year'])
df.head(10)
# Out:
#    gender  past_3_years_bike_related_purchases        DOB  job_title  \
# 0       4                                   99 1953-10-22         38
# 1       4                                   99 1954-03-18         95
# 2       2                                   99 1954-04-02         76
# 3       4                                   99 1954-04-11        145
# 4       4                                   99 1954-05-26          6
# 5       4                                   99 1954-07-24         11
# 6       2                                   99 1954-10-27        145
# 7       4                                   99 1955-04-19         96
# 8       2                                   99 1955-04-25        179
# 9       2                                   99 1955-11-08         38
#
#    job_industry_category  wealth_segment deceased_indicator  owns_car  tenure  \
# 0                      7               2                  N         0     9.0
# ...

# %%
df.drop(['DOB', 'deceased_indicator'], axis=1,inplace=True)
df.head()
# Out:
#    gender  past_3_years_bike_related_purchases  job_title  \
# 0       4                                   99         38
# 1       4                                   99         95
# 2       2                                   99         76
# 3       4                                   99        145
# 4       4                                   99          6
#
#    job_industry_category  wealth_segment  owns_car  tenure  year  month
# 0                      7               2         0     9.0     1   10.0
# 1                      6               0         0     5.0     2    3.0
# 2                      3               0         0     1.0     2    4.0
# 3                      2               0         1     7.0     2    4.0
# 4                      1               2         0    18.0     2    5.0

# %%
fig = plt.figure(figsize = (7,12))
sns.lineplot(x = 'month', y = 'past_3_years_bike_related_purchases', data = df)

# %%
fig = plt.figure(figsize = (22,15))
sns.barplot(x = 'month', y = 'past_3_years_bike_related_purchases', data = df)

# %%
#separating the input variable
import numpy as np
df_x=df.drop(columns=["past_3_years_bike_related_purchases"])
y=df['past_3_years_bike_related_purchases']

# %%
#sacaling down using standardscaler
from sklearn.preprocessing import MinMaxScaler
Mc=MinMaxScaler()
x=Mc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.skew()
x
# Out:
#       gender  job_title  job_industry_category  wealth_segment  owns_car  \
# 0        0.8   0.195876               0.777778             1.0       0.0
# 1        0.8   0.489691               0.666667             0.0       0.0
# 2        0.4   0.391753               0.333333             0.0       0.0
# 3        0.8   0.747423               0.222222             0.0       1.0
# 4        0.8   0.030928               0.111111             1.0       0.0
# ...      ...        ...                    ...             ...       ...
# 3995     0.4   0.896907               0.555556             1.0       1.0
# 3996     0.4   0.752577               0.888889             1.0       0.0
# 3997     0.4   0.788660               0.333333             1.0       0.0
# 3998     0.8   0.773196               0.222222             1.0       1.0
# 3999     0.4   0.489691               0.666667             0.0       1.0
#
#         tenure      year
# 0     0.380952  0.012821
# 1     0.190476  0.025641
# ...

# %%
y.skew()
y
# Out:
# 0       99
# 1       99
# 2       99
# 3       99
# 4       99
#         ..
# 3995     0
# 3996     0
# 3997     0
# 3998     0
# 3999     0
# Name: past_3_years_bike_related_purchases, Length: 4000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 55,test_size=0.20)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,x,y):
    max_r_score=-10
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ", final_r_state,"is",max_r_score)
    return final_r_state

# %%
df.isnull().sum()
# Out:
# gender                                 0
# past_3_years_bike_related_purchases    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# owns_car                               0
# tenure                                 0
# year                                   0
# dtype: int64

# %%
df.dropna(axis = 0, how ='all', inplace = True)

# %%
df.isnull().sum()
# Out:
# gender                                 0
# past_3_years_bike_related_purchases    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# owns_car                               0
# tenure                                 0
# year                                   0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                                   int32
# past_3_years_bike_related_purchases      int64
# job_title                                int32
# job_industry_category                    int32
# wealth_segment                           int32
# owns_car                                 int32
# tenure                                 float64
# year                                     int64
# dtype: object

# %%
df['tenure'].astype(np.int64)
# Out:
# 0        9
# 1        5
# 2        1
# 3        7
# 4       18
#         ..
# 3995     5
# 3996     7
# 3997     4
# 3998    16
# 3999    13
# Name: tenure, Length: 4000, dtype: int64

# %%
np.where(x.values >= np.finfo(np.float64).max)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater_equal
#   """Entry point for launching an IPython kernel.
# (array([], dtype=int64), array([], dtype=int64))

# %%
df.dtypes
# Out:
# gender                                   int32
# past_3_years_bike_related_purchases      int64
# job_title                                int32
# job_industry_category                    int32
# wealth_segment                           int32
# owns_car                                 int32
# tenure                                 float64
# year                                     int64
# dtype: object

# %%
df['tenure'] = df['tenure'].fillna(0).astype(np.int64)
print (df['tenure'])
# Out:
# 0        9
# 1        5
# 2        1
# 3        7
# 4       18
#         ..
# 3995     5
# 3996     7
# 3997     4
# 3998    16
# 3999    13
# Name: tenure, Length: 4000, dtype: int64

# %%
df.dtypes
# Out:
# gender                                 int32
# past_3_years_bike_related_purchases    int64
# job_title                              int32
# job_industry_category                  int32
# wealth_segment                         int32
# owns_car                               int32
# tenure                                 int64
# year                                   int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 55,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
lrreg=LinearRegression()
r_state=maxr2_score(lrreg,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  -0.01392258008847369
# r2_score corresponding to random state:  43 is:  -0.003004325855613832
# r2_score corresponding to random state:  44 is:  -0.0022530995820286837
# r2_score corresponding to random state:  45 is:  -0.007580375079765389
# r2_score corresponding to random state:  46 is:  -0.00010697832186989942
# r2_score corresponding to random state:  47 is:  -0.004087011908364913
# r2_score corresponding to random state:  48 is:  -0.003945665200945081
# r2_score corresponding to random state:  49 is:  -0.0021791262401478217
# r2_score corresponding to random state:  50 is:  -0.0047619211099982905
# r2_score corresponding to random state:  51 is:  -0.004461929081770011
# r2_score corresponding to random state:  52 is:  -0.004381328663828565
# r2_score corresponding to random state:  53 is:  -0.005287298224658787
# r2_score corresponding to random state:  54 is:  -0.007195518391960087
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 28}

# %%
#knn max r2 score
knr=KNeighborsRegressor(n_neighbors=28)
r_state=maxr2_score(knr,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  -0.01392258008847369
# r2_score corresponding to random state:  43 is:  -0.003004325855613832
# r2_score corresponding to random state:  44 is:  -0.0022530995820286837
# r2_score corresponding to random state:  45 is:  -0.007580375079765389
# r2_score corresponding to random state:  46 is:  -0.00010697832186989942
# r2_score corresponding to random state:  47 is:  -0.004087011908364913
# r2_score corresponding to random state:  48 is:  -0.003945665200945081
# r2_score corresponding to random state:  49 is:  -0.0021791262401478217
# r2_score corresponding to random state:  50 is:  -0.0047619211099982905
# r2_score corresponding to random state:  51 is:  -0.004461929081770011
# r2_score corresponding to random state:  52 is:  -0.004381328663828565
# r2_score corresponding to random state:  53 is:  -0.005287298224658787
# r2_score corresponding to random state:  54 is:  -0.007195518391960087
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression:",cross_val_score(lrreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression:",cross_val_score(lrreg,x,y,cv=5,scoring='r2').std())
print()
print("Mean r2 score for KNN Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNN Regression:",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
# based on output KNN Regression is Performing well
# Out:
# Mean r2 score for Linear Regression: -35.35275917770712
# standard deviation in r2 score for Linear Regression: 28.224505661618355
#
# Mean r2 score for KNN Regression:  -36.16157475573188
# standard deviation in r2 score for KNN Regression: 28.101338955075136

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
lsreg=Lasso(alpha=1)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  -0.01392258008847369
# r2_score corresponding to random state:  43 is:  -0.003004325855613832
# r2_score corresponding to random state:  44 is:  -0.0022530995820286837
# r2_score corresponding to random state:  45 is:  -0.007580375079765389
# r2_score corresponding to random state:  46 is:  -0.00010697832186989942
# r2_score corresponding to random state:  47 is:  -0.004087011908364913
# r2_score corresponding to random state:  48 is:  -0.003945665200945081
# r2_score corresponding to random state:  49 is:  -0.0021791262401478217
# r2_score corresponding to random state:  50 is:  -0.0047619211099982905
# r2_score corresponding to random state:  51 is:  -0.004461929081770011
# r2_score corresponding to random state:  52 is:  -0.004381328663828565
# r2_score corresponding to random state:  53 is:  -0.005287298224658787
# r2_score corresponding to random state:  54 is:  -0.007195518391960087
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
# based on output Lasso Regression is Performing as linear Regression
# Out:
# Mean r2 score for Lasso Regression: -35.29334427154349
# standard deviation in r2 score for Lasso Regression: 28.20171592471188

# %%
# gradient Boosting
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.001, 'n_estimators': 10}

# %%
gbr=GradientBoostingRegressor(learning_rate = 0.001, n_estimators=10)

# %%
r_state=maxr2_score(gbr,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  -0.01392258008847369
# r2_score corresponding to random state:  43 is:  -0.003004325855613832
# r2_score corresponding to random state:  44 is:  -0.0022530995820286837
# r2_score corresponding to random state:  45 is:  -0.007580375079765389
# r2_score corresponding to random state:  46 is:  -0.00010697832186989942
# r2_score corresponding to random state:  47 is:  -0.004087011908364913
# r2_score corresponding to random state:  48 is:  -0.003945665200945081
# r2_score corresponding to random state:  49 is:  -0.0021791262401478217
# r2_score corresponding to random state:  50 is:  -0.0047619211099982905
# r2_score corresponding to random state:  51 is:  -0.004461929081770011
# r2_score corresponding to random state:  52 is:  -0.004381328663828565
# r2_score corresponding to random state:  53 is:  -0.005287298224658787
# r2_score corresponding to random state:  54 is:  -0.007195518391960087
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Gradientboosting Regressor:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for GradientbootingRegressir:",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Gradientboosting Regressor: -35.293368624053564
# standard deviation in r2 score for GradientbootingRegressir: 28.201752258046092

# %%
from sklearn.model_selection import cross_val_score
print("max r2 score for Gradientboosting Regressor:",cross_val_score(gbr,x,y,cv=5,scoring="r2").max())
print("standard deviation in r2 score for GradientbootingRegressir:",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# max r2 score for Gradientboosting Regressor: -0.01987023495725082
# standard deviation in r2 score for GradientbootingRegressir: 28.20175225804609

# %%
#even after trying several algorithms no observable changes exept knn, knnregression linear regression model was good can be adopted
from sklearn.externals import joblib
joblib.dump(lrreg,'project_lr.pkl')
# Out:
# ['project_lr.pkl']
